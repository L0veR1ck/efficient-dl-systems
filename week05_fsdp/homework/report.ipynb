# %% [markdown]
# # Environment

# %%
# !nvidia-smi
# Out:
# Fri Mar 13 00:54:13 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.28.03              Driver Version: 560.28.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A4000               Off |   00000000:3B:00.0 Off |                  Off |
# | 41%   48C    P2            135W /  140W |   14737MiB /  16376MiB |     97%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %env CUDA_VISIBLE_DEVICES=4,5,6,7
# Out:
# env: CUDA_VISIBLE_DEVICES=4,5,6,7

# %% [markdown]
# # FSDP2 references

# %% [markdown]
# ![screenshot](artifacts/fsdp2_snapshots/Screenshot%202026-03-13%20at%2006.21.12.png)

# %% [markdown]
# ![screenshot](artifacts/fsdp2_traces/Screenshot%202026-03-13%20at%2006.22.30.png)

# %% [markdown]
# # Tests

# %%
# !pytest test.py::test_fsdp
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-9.0.2, pluggy-1.6.0
# rootdir: /home/pliskovskijla/efficient-dl-systems/week05_fsdp/homework
# configfile: pyproject.toml
# plugins: typeguard-4.4.4, anyio-4.12.1
# collected 4 items
#
# test.py ....                                                             [100%]
#
# =============================== warnings summary ===============================
# .venv/lib/python3.12/site-packages/torch/jit/_script.py:362: 14 warnings
#   /home/pliskovskijla/efficient-dl-systems/week05_fsdp/homework/.venv/lib/python3.12/site-packages/torch/jit/_script.py:362: DeprecationWarning: `torch.jit.script_method` is deprecated. Please switch to `torch.compile` or `torch.export`.
#     warnings.warn(
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================= 4 passed, 14 warnings in 41.99s ========================

# %% [markdown]
# # FSDP2

# %% [markdown]
# # Task 1

# %% [markdown]
# ![screenshot](artifacts/task1/effdl_snapshots/Screenshot%202026-03-13%20at%2006.14.21.png)

# %% [markdown]
# # Task 2

# %% [markdown]
# Снэпшоты и трейсы не сохранились, потому что у меня было неправильно реализовано ожидание конца копирования после all-gather в pre-forward, а исправил этот баг я уже только после третьего задания

# %% [markdown]
# # Task 3

# %% [markdown]
# ![screenshot](artifacts/task3/effdl_snapshots/Screenshot%202026-03-13%20at%2006.17.17.png)

# %% [markdown]
# ![screenshot](artifacts/task3/effdl_traces/Screenshot%202026-03-13%20at%2006.23.05.png)

# %% [markdown]
# # Bonus 1

# %%
# !pytest test.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-9.0.2, pluggy-1.6.0
# rootdir: /home/pliskovskijla/efficient-dl-systems/week05_fsdp/homework
# configfile: pyproject.toml
# plugins: typeguard-4.4.4, anyio-4.12.1
# collected 8 items
#
# test.py ........                                                         [100%]
#
# =============================== warnings summary ===============================
# .venv/lib/python3.12/site-packages/torch/jit/_script.py:362: 14 warnings
#   /home/pliskovskijla/efficient-dl-systems/week05_fsdp/homework/.venv/lib/python3.12/site-packages/torch/jit/_script.py:362: DeprecationWarning: `torch.jit.script_method` is deprecated. Please switch to `torch.compile` or `torch.export`.
#     warnings.warn(
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================== 8 passed, 14 warnings in 76.12s (0:01:16) ===================

# %% [markdown]
# ![screenshot](artifacts/bonus1/effdl_snapshots/Screenshot%202026-03-13%20at%2006.17.49.png)

# %% [markdown]
# ![screenshot](artifacts/bonus1/effdl_traces/Screenshot%202026-03-13%20at%2006.24.16.png)

# %% [markdown]
# ## FSDP2 references

# %% [markdown]
# ![screenshot](artifacts/fsdp2_no_reshard_after_forward_snapshots/Screenshot%202026-03-13%20at%2006.20.55.png)

# %% [markdown]
# ![screenshot](artifacts/fsdp2_no_reshard_after_forward_traces/Screenshot%202026-03-13%20at%2006.24.45.png)
